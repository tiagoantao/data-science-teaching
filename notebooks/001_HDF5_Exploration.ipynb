# %%
import tables
import numpy as np
import pandas as pd

# %%
fname = '../raw/ag1000g.phase1.ar3.pass.3L.h5'

# %%
#store = pd.HDFStore(fname, 'r')
store = tables.open_file(fname, 'r')

# %%
store
# Out:
# File(filename=../raw/ag1000g.phase1.ar3.pass.3L.h5, title='', mode='r', root_uep='/', filters=Filters(complevel=0, shuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) ''
# /3L (Group) ''
# /3L/samples (Array(765,)) ''
#   atom := StringAtom(itemsize=8, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := None
# /3L/calldata (Group) ''
# /3L/calldata/AD (EArray(9643193, 765, 4), zlib(3)) ''
#   atom := UInt16Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (1638, 10, 4)
# /3L/calldata/DP (EArray(9643193, 765), zlib(3)) ''
#   atom := UInt16Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (6553, 10)
# /3L/calldata/GQ (EArray(9643193, 765), zlib(3)) ''
#   atom := UInt8Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (13107, 10)
# /3L/calldata/genotype (EArray(9643193, 765, 2), zlib(3)) ''
#   atom := Int8Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (6553, 10, 2)
# /3L/calldata/is_called (EArray(9643193, 765), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (13107, 10)
# /3L/variants (Group) ''
# /3L/variants/ABHet (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/ABHom (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/AC (EArray(9643193, 3), zlib(3)) ''
#   atom := UInt16Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (21845, 3)
# /3L/variants/AF (EArray(9643193, 3), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (21845, 3)
# /3L/variants/ALT (EArray(9643193, 3), zlib(3)) ''
#   atom := StringAtom(itemsize=1, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (43690, 3)
# /3L/variants/AN (EArray(9643193,), zlib(3)) ''
#   atom := UInt16Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/ANN (Table(9643193,), zlib(3)) ''
#   description := {
#   "Allele": StringCol(itemsize=12, shape=(), dflt=b'', pos=0),
#   "Annotation": StringCol(itemsize=34, shape=(), dflt=b'', pos=1),
#   "Annotation_Impact": StringCol(itemsize=8, shape=(), dflt=b'', pos=2),
#   "Gene_Name": StringCol(itemsize=14, shape=(), dflt=b'', pos=3),
#   "Gene_ID": StringCol(itemsize=14, shape=(), dflt=b'', pos=4),
#   "Feature_Type": StringCol(itemsize=20, shape=(), dflt=b'', pos=5),
#   "Feature_ID": StringCol(itemsize=14, shape=(), dflt=b'', pos=6),
#   "Transcript_BioType": StringCol(itemsize=20, shape=(), dflt=b'', pos=7),
#   "Rank": Int8Col(shape=(), dflt=0, pos=8),
#   "HGVS_c": StringCol(itemsize=12, shape=(), dflt=b'', pos=9),
#   "HGVS_p": StringCol(itemsize=14, shape=(), dflt=b'', pos=10),
#   "cDNA_pos": Int32Col(shape=(), dflt=0, pos=11),
#   "cDNA_length": Int32Col(shape=(), dflt=0, pos=12),
#   "CDS_pos": Int32Col(shape=(), dflt=0, pos=13),
#   "CDS_length": Int32Col(shape=(), dflt=0, pos=14),
#   "AA_pos": Int32Col(shape=(), dflt=0, pos=15),
#   "AA_length": Int32Col(shape=(), dflt=0, pos=16),
#   "Distance": Int32Col(shape=(), dflt=0, pos=17)}
#   byteorder := 'little'
#   chunkshape := (686,)
# /3L/variants/Accessible (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/BaseCounts (EArray(9643193, 4), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (10922, 3)
# /3L/variants/BaseQRankSum (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/CHROM (EArray(9643193,), zlib(3)) ''
#   atom := StringAtom(itemsize=12, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (10922,)
# /3L/variants/Coverage (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/CoverageMQ0 (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/DP (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/DS (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/Dels (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/FILTER_FS (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_HRun (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_HighCoverage (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_HighMQ0 (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_LowCoverage (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_LowMQ (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_LowQual (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_NoCoverage (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_PASS (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_QD (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_ReadPosRankSum (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_RefN (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FILTER_RepeatDUST (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/FS (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/HRun (EArray(9643193,), zlib(3)) ''
#   atom := UInt8Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (131072,)
# /3L/variants/HW (EArray(9643193,), zlib(3)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/HaplotypeScore (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/HighCoverage (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/HighMQ0 (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/InbreedingCoeff (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/LOF (EArray(9643193,), zlib(3)) ''
#   atom := StringAtom(itemsize=12, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (10922,)
# /3L/variants/LowCoverage (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/LowMQ (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/LowPairing (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/MLEAC (EArray(9643193, 3), zlib(3)) ''
#   atom := UInt16Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (21845, 3)
# /3L/variants/MLEAF (EArray(9643193, 3), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (21845, 3)
# /3L/variants/MQ (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/MQ0 (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/MQRankSum (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/NDA (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/NMD (EArray(9643193,), zlib(3)) ''
#   atom := StringAtom(itemsize=12, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (10922,)
# /3L/variants/NoCoverage (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/OND (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/POS (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/QD (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/QUAL (EArray(9643193,), zlib(3)) ''
#   atom := Float32Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)
# /3L/variants/REF (EArray(9643193,), zlib(3)) ''
#   atom := StringAtom(itemsize=1, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (131072,)
# /3L/variants/RPA (EArray(9643193,), zlib(3)) ''
#   atom := UInt16Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/RU (EArray(9643193,), zlib(3)) ''
#   atom := StringAtom(itemsize=12, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (10922,)
# /3L/variants/ReadPosRankSum (EArray(9643193,), zlib(3)) ''
#   atom := Float16Atom(shape=(), dflt=0.0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (65536,)
# /3L/variants/RefMasked (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/RefN (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/RepeatDUST (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/RepeatMasker (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/RepeatTRF (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/STR (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/VariantType (EArray(9643193,), zlib(3)) ''
#   atom := StringAtom(itemsize=12, shape=(), dflt=b'')
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (10922,)
# /3L/variants/is_snp (EArray(9643193,), zlib(3)) ''
#   atom := EnumAtom(enum=Enum({'TRUE': 1, 'FALSE': 0}), dflt='TRUE', base=Int8Atom(shape=(), dflt=0), shape=())
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (131072,)
# /3L/variants/num_alleles (EArray(9643193,), zlib(3)) ''
#   atom := UInt8Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'irrelevant'
#   chunkshape := (131072,)
# /3L/variants/svlen (EArray(9643193,), zlib(3)) ''
#   atom := Int32Atom(shape=(), dflt=0)
#   maindim := 0
#   flavor := 'numpy'
#   byteorder := 'little'
#   chunkshape := (32768,)

# %%
for n in store.get_node('/3L'):
    print(n)
# Out:
# /3L/calldata (Group) ''
# /3L/samples (Array(765,)) ''
# /3L/variants (Group) ''

# %%
call_data = store.get_node('/3L').calldata
samples = store.get_node('/3L/samples')
variants = store.get_node('/3L/variants')
variants.POS[-1]
# Out:
# 41956556

# %%
samples[:10]

# %%
# store['/3L/variants/ANN']  # no no no!

# %%
# no no no
#for rec in store['/3L/variants/ANN']:
#    print(rec)
#    break

# %%
for rec in store.select('/3L/variants/ANN', iterator=True):
    print(rec)
    break
# Out:
# /core/software/conda/lib/python3.5/site-packages/pandas/io/pytables.py:3089: IncompatibilityWarning:
# where criteria is being ignored as this version [0.0.0] is too old (or
# not-defined), read the file in and write it out to a new file to upgrade (with
# the copy_to method)
#
#   warnings.warn(ws, IncompatibilityWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-60e250ba059f> in <module>()
# ----> 1 for rec in store.select('/3L/variants/ANN', iterator=True):
#       2     print(rec)
#       3     break
#
# /core/software/conda/lib/python3.5/site-packages/pandas/io/pytables.py in __iter__(self)
#    1330
#    1331             stop = min(current + self.chunksize, self.stop)
# -> 1332             value = self.func(None, None, self.coordinates[current:stop])
#    1333             current = stop
#    1334             if value is None or not len(value):
#
# /core/software/conda/lib/python3.5/site-packages/pandas/io/pytables.py in func(_start, _stop, _where)
#     671             return s.read(start=_start, stop=_stop,
#     672                           where=_where,
# --> 673                           columns=columns, **kwargs)
#     674
#     675         # create the iterator
#
# /core/software/conda/lib/python3.5/site-packages/pandas/io/pytables.py in read(self, where, columns, **kwargs)
#    4052
#    4053             block = make_block(values, placement=np.arange(len(cols_)))
# -> 4054             mgr = BlockManager([block], [cols_, index_])
#    4055             frames.append(DataFrame(mgr))
#    4056
#
# /core/software/conda/lib/python3.5/site-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check, fastpath)
#    2535
#    2536         if do_integrity_check:
# -> 2537             self._verify_integrity()
#    2538
#    2539         self._consolidate_check()
#
# /core/software/conda/lib/python3.5/site-packages/pandas/core/internals.py in _verify_integrity(self)
#    2745         for block in self.blocks:
#    2746             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 2747                 construction_error(tot_items, block.shape[1:], self.axes)
#    2748         if len(self.items) != tot_items:
#    2749             raise AssertionError('Number of manager items must equal union of '
#
# /core/software/conda/lib/python3.5/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    3897         raise ValueError("Empty data passed with indices specified.")
#    3898     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 3899         passed, implied))
#    3900
#    3901
#
# ValueError: Shape of passed values is (1, 100000), indices imply (1, 9643193)

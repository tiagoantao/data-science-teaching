# %%
import rpy2.robjects as robjects
import rpy2.robjects.lib.ggplot2 as ggplot2

# %load_ext rpy2.ipython
# Out:
# /core/software/conda/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: During startup -
#   warnings.warn(x, RRuntimeWarning)
# /core/software/conda/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: Warning messages:
#
#   warnings.warn(x, RRuntimeWarning)
# /core/software/conda/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: 1: Setting LC_CTYPE failed, using "C"
#
#   warnings.warn(x, RRuntimeWarning)
# /core/software/conda/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: 2: Setting LC_COLLATE failed, using "C"
#
#   warnings.warn(x, RRuntimeWarning)
# /core/software/conda/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: 3: Setting LC_TIME failed, using "C"
#
#   warnings.warn(x, RRuntimeWarning)
# /core/software/conda/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: 4: Setting LC_MESSAGES failed, using "C"
#
# ...

# %%
meta_data = %R read.delim('../raw/samples.all.txt', header=TRUE, stringsAsFactors=FALSE)

# %%
meta_data
# Out:
#      index   ox_code src_code sra_sample_accession population       country  \
# 1        0  AB0085-C    BF2-4            ERS223996        BFS  Burkina Faso
# 2        1  AB0087-C    BF3-3            ERS224013        BFM  Burkina Faso
# 3        2  AB0088-C    BF3-5            ERS223991        BFM  Burkina Faso
# 4        3  AB0089-C    BF3-8            ERS224031        BFM  Burkina Faso
# 5        4  AB0090-C   BF3-10            ERS223936        BFM  Burkina Faso
# 6        5  AB0091-C   BF3-12            ERS224065        BFM  Burkina Faso
# 7        6  AB0092-C   BF3-13            ERS224043        BFM  Burkina Faso
# 8        7  AB0094-C   BF3-17            ERS224057        BFM  Burkina Faso
# 9        8  AB0095-C    BF4-1            ERS224021        BFM  Burkina Faso
# 10       9  AB0097-C    BF4-5            ERS224030        BFM  Burkina Faso
# 11      10  AB0098-C    BF4-6            ERS223999        BFM  Burkina Faso
# ...

# %%
# %R print(meta_data)
# Out:
# Error in print(meta_data) : object 'meta_data' not found
# /core/software/conda/lib/python3.5/site-packages/rpy2/rinterface/__init__.py:185: RRuntimeWarning: Error in print(meta_data) : object 'meta_data' not found
#
#   warnings.warn(x, RRuntimeWarning)

# %%
type(meta_data)
# Out:
# pandas.core.frame.DataFrame

# %%
meta_data.columns
# Out:
# Index(['index', 'ox_code', 'src_code', 'sra_sample_accession', 'population',
#        'country', 'region', 'contributor', 'contact', 'year', 'm_s', 'sex',
#        'n_sequences', 'mean_coverage', 'latitude', 'longitude', 'kt_2la',
#        'kt_2rb', 'kdr_1014', 'rdl_296', 'f_roh_100kb', 'count_roh_100kb',
#        'sum_roh_100kb', 'pca_3R_free_pc1', 'pca_3R_free_pc2',
#        'pca_3R_free_pc3', 'pca_3R_free_pc4', 'pca_3L_free_pc1',
#        'pca_3L_free_pc2', 'pca_3L_free_pc3', 'pca_3L_free_pc4', 'pca_2La_pc1',
#        'pca_2La_pc2', 'pca_2La_pc3', 'pca_2La_pc4', 'pca_2Rb_pc1',
#        'pca_2Rb_pc2', 'pca_2Rb_pc3', 'pca_2Rb_pc4'],
#       dtype='object')

# %%
keep = ['ox_code', 'country', 'sex']
for column in meta_data.columns:
    if column not in keep:
        del meta_data[column]

# %%
meta_data
# Out:
#       ox_code       country sex
# 1    AB0085-C  Burkina Faso   F
# 2    AB0087-C  Burkina Faso   F
# 3    AB0088-C  Burkina Faso   F
# 4    AB0089-C  Burkina Faso   F
# 5    AB0090-C  Burkina Faso   F
# 6    AB0091-C  Burkina Faso   F
# 7    AB0092-C  Burkina Faso   F
# 8    AB0094-C  Burkina Faso   F
# 9    AB0095-C  Burkina Faso   F
# 10   AB0097-C  Burkina Faso   F
# 11   AB0098-C  Burkina Faso   F
# 12   AB0099-C  Burkina Faso   F
# 13   AB0100-C  Burkina Faso   F
# 14   AB0101-C  Burkina Faso   F
# 15   AB0103-C  Burkina Faso   F
# 16   AB0104-C  Burkina Faso   F
# 17   AB0109-C  Burkina Faso   F
# 18   AB0110-C  Burkina Faso   F
# 19   AB0111-C  Burkina Faso   F
# 20   AB0112-C  Burkina Faso   F
# 21   AB0113-C  Burkina Faso   F
# 22   AB0114-C  Burkina Faso   F
# 23   AB0117-C  Burkina Faso   M
# 24   AB0119-C  Burkina Faso   M
# 25   AB0122-C  Burkina Faso   M
# 26   AB0123-C  Burkina Faso   M
# 27   AB0124-C  Burkina Faso   M
# 28   AB0126-C  Burkina Faso   M
# ...

# %%
# %R -i meta_data

# %%
# %R print(meta_data)
# Out:
#      ox_code       country sex
# 1   AB0085-C  Burkina Faso   F
# 2   AB0087-C  Burkina Faso   F
# 3   AB0088-C  Burkina Faso   F
# 4   AB0089-C  Burkina Faso   F
# 5   AB0090-C  Burkina Faso   F
# 6   AB0091-C  Burkina Faso   F
# 7   AB0092-C  Burkina Faso   F
# 8   AB0094-C  Burkina Faso   F
# 9   AB0095-C  Burkina Faso   F
# 10  AB0097-C  Burkina Faso   F
# 11  AB0098-C  Burkina Faso   F
# 12  AB0099-C  Burkina Faso   F
# 13  AB0100-C  Burkina Faso   F
# 14  AB0101-C  Burkina Faso   F
# 15  AB0103-C  Burkina Faso   F
# 16  AB0104-C  Burkina Faso   F
# 17  AB0109-C  Burkina Faso   F
# 18  AB0110-C  Burkina Faso   F
# 19  AB0111-C  Burkina Faso   F
# 20  AB0112-C  Burkina Faso   F
# 21  AB0113-C  Burkina Faso   F
# 22  AB0114-C  Burkina Faso   F
# 23  AB0117-C  Burkina Faso   M
# 24  AB0119-C  Burkina Faso   M
# 25  AB0122-C  Burkina Faso   M
# 26  AB0123-C  Burkina Faso   M
# 27  AB0124-C  Burkina Faso   M
# 28  AB0126-C  Burkina Faso   M
# 29  AB0127-C  Burkina Faso   M
# ...

# %%
# %%R
# bar <- ggplot(meta_data) +  aes(factor(country)) + geom_bar() + theme(axis.text.x = element_text(angle = 90, hjust = 1))
# print(bar)

# %%
# %%R
# bar <- ggplot(meta_data) +  aes(factor(sex)) + geom_bar() + theme(axis.text.x = element_text(angle = 90, hjust = 1))
# print(bar)
